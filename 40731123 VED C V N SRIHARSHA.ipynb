# %%
pip install SoundFile
# Out:
# Requirement already satisfied: SoundFile in c:\users\harsha cvn\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: cffi>=1.0 in c:\users\harsha cvn\anaconda3\lib\site-packages (from SoundFile) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\harsha cvn\anaconda3\lib\site-packages (from cffi>=1.0->SoundFile) (2.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as nup
import glob
import soundfile
import os
import sys

# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\harsha cvn\anaconda3\lib\site-packages (0.10.0.post1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\harsha cvn\anaconda3\lib\site-packages (from librosa) (3.0.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\harsha cvn\anaconda3\lib\site-packages (from librosa) (0.24.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\harsha cvn\anaconda3\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\harsha cvn\anaconda3\lib\site-packages (from librosa) (0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\harsha cvn\anaconda3\lib\site-packages (from librosa) (1.20.3)
# Requirement already satisfied: msgpack>=1.0 in c:\users\harsha cvn\anaconda3\lib\site-packages (from librosa) (1.0.2)
# Requirement already satisfied: pooch>=1.0 in c:\users\harsha cvn\anaconda3\lib\site-packages (from librosa) (1.7.0)
# Requirement already satisfied: numba>=0.51.0 in c:\users\harsha cvn\anaconda3\lib\site-packages (from librosa) (0.54.1)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\harsha cvn\anaconda3\lib\site-packages (from librosa) (5.1.0)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\harsha cvn\anaconda3\lib\site-packages (from librosa) (0.3.4)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\harsha cvn\anaconda3\lib\site-packages (from librosa) (1.7.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\harsha cvn\anaconda3\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\harsha cvn\anaconda3\lib\site-packages (from librosa) (4.5.0)
# Requirement already satisfied: setuptools in c:\users\harsha cvn\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (58.0.4)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in c:\users\harsha cvn\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.37.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\harsha cvn\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.26.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\harsha cvn\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (21.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\harsha cvn\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (3.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\harsha cvn\anaconda3\lib\site-packages (from packaging>=20.0->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\harsha cvn\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\harsha cvn\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\harsha cvn\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\harsha cvn\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2021.10.8)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\harsha cvn\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\harsha cvn\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\harsha cvn\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.20)

# %%
import pandas as pd
import numpy as nup
import glob
import soundfile
import os
import sys

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %%
from IPython.display import Audio

# %%
import warnings
if not sys.warnoptions:
  warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
RavdessData = "C:\\Users\\Harsha CVN\\Downloads\\HCL\\speech-emotion-recognition-ravdess-data\\"

# %%
import os
import pandas
ravdessDirectoryList = os.listdir(RavdessData)
fileEmotion = []
filePath = []
for dir in ravdessDirectoryList:
    actor = os.listdir(RavdessData + dir)
    for file in actor:
        part = file.split(".")[0]
        part = part.split("-")
        fileEmotion.append(int(part[2]))
        filePath.append(RavdessData + dir + '/' + file)
emotion_df = pandas.DataFrame(fileEmotion, columns=['Emotions'])  
path_df = pandas.DataFrame(filePath, columns=['Path'])
Ravdess_df = pandas.concat([emotion_df, path_df], axis=1 )

# %%
Ravdess_df.Emotions.replace({1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 8:'surprise'}, inplace=True)
Ravdess_df.head(50)
# Out:
#    Emotions                                               Path
# 0   neutral  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 1   neutral  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 2   neutral  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 3   neutral  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 4      calm  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 5      calm  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 6      calm  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 7      calm  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 8      calm  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 9      calm  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 10     calm  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 11     calm  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 12    happy  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 13    happy  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 14    happy  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 15    happy  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 16    happy  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 17    happy  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 18    happy  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 19    happy  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 20      sad  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 21      sad  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 22      sad  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 23      sad  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 24      sad  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 25      sad  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 26      sad  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 27      sad  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 28    angry  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 29    angry  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 30    angry  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 31    angry  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 32    angry  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 33    angry  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 34    angry  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 35    angry  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 36     fear  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 37     fear  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 38     fear  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 39     fear  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 40     fear  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 41     fear  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 42     fear  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 43     fear  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 44  disgust  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 45  disgust  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 46  disgust  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 47  disgust  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 48  disgust  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 49  disgust  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...

# %%
data_path = pandas.concat([Ravdess_df], axis = 0)
data_path.to_csv("data_path.csv",index=False)
data_path.head()
# Out:
#   Emotions                                               Path
# 0  neutral  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 1  neutral  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 2  neutral  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 3  neutral  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...
# 4     calm  C:\Users\Harsha CVN\Downloads\HCL\speech-emoti...

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\harsha cvn\anaconda3\lib\site-packages (3.4.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\harsha cvn\anaconda3\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\harsha cvn\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\harsha cvn\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: numpy>=1.16 in c:\users\harsha cvn\anaconda3\lib\site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harsha cvn\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\harsha cvn\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: six in c:\users\harsha cvn\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\harsha cvn\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\harsha cvn\anaconda3\lib\site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\harsha cvn\anaconda3\lib\site-packages (from seaborn) (1.20.3)
# Requirement already satisfied: scipy>=1.0 in c:\users\harsha cvn\anaconda3\lib\site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\harsha cvn\anaconda3\lib\site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\harsha cvn\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\harsha cvn\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harsha cvn\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\harsha cvn\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\harsha cvn\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: six in c:\users\harsha cvn\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\harsha cvn\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn[stats]
# Out:
# Requirement already satisfied: seaborn[stats] in c:\users\harsha cvn\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\harsha cvn\anaconda3\lib\site-packages (from seaborn[stats]) (1.7.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\harsha cvn\anaconda3\lib\site-packages (from seaborn[stats]) (1.20.3)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\harsha cvn\anaconda3\lib\site-packages (from seaborn[stats]) (3.4.3)
# Requirement already satisfied: pandas>=0.23 in c:\users\harsha cvn\anaconda3\lib\site-packages (from seaborn[stats]) (1.3.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\harsha cvn\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn[stats]) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harsha cvn\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn[stats]) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\harsha cvn\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn[stats]) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\harsha cvn\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn[stats]) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\harsha cvn\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn[stats]) (8.4.0)
# Requirement already satisfied: six in c:\users\harsha cvn\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn[stats]) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\harsha cvn\anaconda3\lib\site-packages (from pandas>=0.23->seaborn[stats]) (2021.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: seaborn 0.11.2 does not provide the extra 'stats'

# %%
from matplotlib import pyplot as mplt
import seaborn as sbn
import librosa.display
sbn.countplot(x='Emotions',data=data_path)
mplt.title('Count of Emotions', size=16)
mplt.xlabel('Emotions', size=24)
mplt.ylabel('Count', size=24)
sbn.despine(top=True, right=True, left=True, bottom=True)
mplt.show()

# %%
def create_waveplot(data, sr, e):
    mplt.figure(figsize=(10, 3))
    mplt.title('Waveplot for audio with {} emotion'.format(e), size=15)
    librosa.display.waveshow(data, sr=sr)
    mplt.show()

# %%
def create_spectrogram(data, sr, e):
    # stft function converts the data into short term fourier transform
    X = librosa.stft(data)
    Xdb = librosa.amplitude_to_db(abs(X))
    mplt.figure(figsize=(12, 3))
    mplt.title('Spectrogram for audio with {} emotion'.format(e), size=15)
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')   
    #librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
    mplt.colorbar()

# %%
emotion='fear'
path = nup.array(data_path.Path[data_path.Emotions==emotion])[1]
data, sampling_rate = librosa.load(path)
librosa.display.waveshow(data, sr=sampling_rate)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion='angry'
path = nup.array(data_path.Path[data_path.Emotions==emotion])[1]
data, sampling_rate = librosa.load(path)
librosa.display.waveshow(data, sr=sampling_rate)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion='happy'
path = nup.array(data_path.Path[data_path.Emotions==emotion])[1]
data, sampling_rate = librosa.load(path)
librosa.display.waveshow(data, sr=sampling_rate)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def noise(data):
    noiseAmp = 0.035*nup.random.uniform()*nup.amax(data)
    data = data + noiseAmp*nup.random.normal(size=data.shape[0])
    return data

def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate=0.8)

def shift(data):
    shiftRange = int(nup.random.uniform(low=-5, high = 5)*1000)
    return nup.roll(data, shiftRange)

def pitch(data, samplingRate, pitchFactor=0.7):
    return librosa.effects.pitch_shift(data, sr=sampling_rate, n_steps=0.7)

# %%
x = noise(data)
mplt.figure(figsize=(14,4))
librosa.display.waveshow(y=x, sr=sampling_rate)
Audio(x, rate=sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x = stretch(data)
mplt.figure(figsize=(14,4))
librosa.display.waveshow(y=x, sr=sampling_rate)
Audio(x, rate=sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x = shift(data)
mplt.figure(figsize=(14,4))
librosa.display.waveshow(y=x, sr=sampling_rate)
Audio(x, rate=sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x = pitch(data, sampling_rate)
mplt.figure(figsize=(14,4))
librosa.display.waveshow(y=x, sr=sampling_rate)
Audio(x, rate=sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def extractFeature(fileName, mfcc, chroma, mel): 
    with soundfile.SoundFile(fileName) as soundFile:
        X = soundFile.read(dtype="float32")
        sampleRate=soundFile.samplerate
        if chroma:
            stft=nup.abs(librosa.stft(X))
        result=nup.array([])
        if mfcc:
            mfccs=nup.mean(librosa.feature.mfcc(y=X, sr=sampleRate, n_mfcc=40).T, axis=0)
            result=nup.hstack((result, mfccs))
        if chroma:
            chroma=nup.mean(librosa.feature.chroma_stft(S=stft, sr=sampleRate).T, axis=0)
            result=nup.hstack((result, chroma))
        if mel:
            mel=nup.mean(librosa.feature.melspectrogram(y=X, sr=sampleRate).T, axis=0)
            result=nup.hstack((result, mel))
    return result

# %%
emotions={
    '01':'neutral', 
    '02':'calm', 
    '03':'happy', 
    '04':'sad', 
    '05':'angry', 
    '06':'fearful', 
    '07':'disgust', 
    '08':'surprised'
}
observedEmotions=['calm', 'happy', 'fearful', 'disgust']

# %%
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
def loadData(test_size=0.2):
    x,y=[],[]
    for file in glob.glob("C:\\Users\\Harsha CVN\\Downloads\\HCL\\speech-emotion-recognition-ravdess-data\\Actor_*\\*.wav"): 
        fileName=os.path.basename(file)
        emotion1=emotions[fileName.split("-")[2]] 
        if emotion1 not in observedEmotions:
            continue
        feature=extractFeature(file, mfcc=True, chroma=True, mel=True)
        x.append(feature)
        y.append(emotion1)
    return train_test_split(nup.array(x), y, test_size=test_size, random_state=9)

# %%
x_train,x_test,y_train,y_test=loadData(test_size=0.23)

# %%
print((x_train.shape[0], x_test.shape[0]))
# Out:
# (591, 177)

# %%
print(f'Features extracted: {x_train.shape[1]}')
# Out:
# Features extracted: 180

# %%
model=MLPClassifier(alpha=0.01, batch_size=256, epsilon=1e-08, hidden_layer_sizes=(300,), learning_rate='adaptive', max_iter=500)

# %%
model.fit(x_train, y_train)
# Out:
# MLPClassifier(alpha=0.01, batch_size=256, hidden_layer_sizes=(300,),
#               learning_rate='adaptive', max_iter=500)

# %%
expected_Of_y = y_test
yPred=model.predict(x_test)

# %%
print(metrics.confusion_matrix(expected_Of_y,yPred))
# Out:
# [[45  4  3  1]
#  [ 1 34  4  7]
#  [ 1  3 27  4]
#  [ 3  4  5 31]]

# %%
print(classification_report(y_test,yPred))
# Out:
#               precision    recall  f1-score   support
#
#         calm       0.90      0.85      0.87        53
#      disgust       0.76      0.74      0.75        46
#      fearful       0.69      0.77      0.73        35
#        happy       0.72      0.72      0.72        43
#
#     accuracy                           0.77       177
#    macro avg       0.77      0.77      0.77       177
# weighted avg       0.78      0.77      0.78       177

# %%
accuracy=accuracy_score(y_true=y_test, y_pred=yPred)
print("Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# Accuracy: 77.40%
